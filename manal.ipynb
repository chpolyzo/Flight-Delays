# %%
import os
import pandas as pd
import numpy as np
import seaborn as sb
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_87 = pd.read_csv('1987.csv')
df_08 = pd.read_csv('2008.csv')

# %%
fields = ['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'ArrDelay', 'CarrierDelay',
       'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay' ]

df_1987 = pd.read_csv('1987.csv', skipinitialspace=True, usecols=fields)
df_1988 = pd.read_csv('1988.csv', skipinitialspace=True, usecols=fields)
df_1989 = pd.read_csv('1989.csv', skipinitialspace=True, usecols=fields)
df_1990 = pd.read_csv('1990.csv', skipinitialspace=True, usecols=fields)
df_1991 = pd.read_csv('1991.csv', skipinitialspace=True, usecols=fields)
df_1992 = pd.read_csv('1992.csv', skipinitialspace=True, usecols=fields)
df_1993 = pd.read_csv('1993.csv', skipinitialspace=True, usecols=fields)
df_1994 = pd.read_csv('1994.csv', skipinitialspace=True, usecols=fields)
df_1995 = pd.read_csv('1995.csv', skipinitialspace=True, usecols=fields)
df_1996 = pd.read_csv('1996.csv', skipinitialspace=True, usecols=fields)
df_1997 = pd.read_csv('1997.csv', skipinitialspace=True, usecols=fields)
df_1998 = pd.read_csv('1998.csv', skipinitialspace=True, usecols=fields)
df_1999 = pd.read_csv('1999.csv', skipinitialspace=True, usecols=fields)
df_2000 = pd.read_csv('2000.csv', skipinitialspace=True, usecols=fields)
df_2001 = pd.read_csv('2001.csv', skipinitialspace=True, usecols=fields)
df_2002 = pd.read_csv('2002.csv', skipinitialspace=True, usecols=fields)
df_2003 = pd.read_csv('2003.csv', skipinitialspace=True, usecols=fields)
df_2004 = pd.read_csv('2004.csv', skipinitialspace=True, usecols=fields)
df_2005 = pd.read_csv('2005.csv', skipinitialspace=True, usecols=fields)
df_2006 = pd.read_csv('2006.csv', skipinitialspace=True, usecols=fields)
df_2007 = pd.read_csv('2007.csv', skipinitialspace=True, usecols=fields)
df_2008 = pd.read_csv('2001.csv', skipinitialspace=True, usecols=fields)
# See the keys
print(df_1988.keys())

# %%
path = 'C:\Users\User\Documents\DAND\fifth_project\aviation_dataset'
fields = ['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'ArrDelay', 'CarrierDelay',
       'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay' ]
for year in range(2009-1987):
    df_name = '1987'
    df_name = str(int(df_name) + 1) + '_df'

# %%
path = "C:/Users/User/Documents/DAND/fifth_project/aviation_dataset"
year_list = os.listdir(path) # a list keeping the names of my .csv files in path directory
fields = ['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'ArrDelay', 'CarrierDelay',
       'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay' ]
df = pd.DataFrame(columns=fields) 
temp_df = pd.DataFrame()
for year in year_list:
    temp_df = pd.read_csv(year, header=0, skipinitialspace=True, usecols=fields)
    df = df.append(temp_df)

# %%
df
# Out:
#          Year Month DayofMonth DayOfWeek  ArrDelay  CarrierDelay  \
# 0        1987    10         14         3      23.0           NaN
# 1        1987    10         15         4      14.0           NaN
# 2        1987    10         17         6      29.0           NaN
# 3        1987    10         18         7      -2.0           NaN
# 4        1987    10         19         1      33.0           NaN
# 5        1987    10         21         3      -1.0           NaN
# 6        1987    10         22         4       3.0           NaN
# 7        1987    10         23         5      13.0           NaN
# 8        1987    10         24         6      19.0           NaN
# 9        1987    10         25         7       2.0           NaN
# 10       1987    10         26         1      15.0           NaN
# 11       1987    10         28         3      24.0           NaN
# 12       1987    10         29         4      11.0           NaN
# ...

# %%
year_list = os.listdir(path)
year_list[0][2:4]
df.append(temp_df, ignore_index=True, sort = False)
# Out:
#          Year  Month  DayofMonth  DayOfWeek  ArrDelay  CarrierDelay  \
# 0        1989      1          23          1     110.0           NaN
# 1        1989      1          24          2      20.0           NaN
# 2        1989      1          25          3     -19.0           NaN
# 3        1989      1          26          4     -29.0           NaN
# 4        1989      1          27          5     -39.0           NaN
# 5        1989      1          28          6      -2.0           NaN
# 6        1989      1          29          7     230.0           NaN
# 7        1989      1          30          1     -21.0           NaN
# 8        1989      1          31          2     155.0           NaN
# 9        1989      1           2          1     -17.0           NaN
# 10       1989      1           3          2      13.0           NaN
# 11       1989      1           4          3      10.0           NaN
# 12       1989      1           5          4      18.0           NaN
# ...

# %%
temp_df = pd.read_csv(year_list[0], skipinitialspace=True, usecols=fields)
temp_df

# %%
year_list[0]

# %%
years = []
for year in range(1987,2009): #1987 inclusive, 2009 exclusive
    
    years.append(year)
years

# %%
df_name

# %%
str(int(df_name) + 1)

# %%
df_name = str(int(df_name) + 1) + '_df'
df_name

# %%
df_87.info()

# %%
df_08.columns

# %%
df_08.info(null_counts = True)

# %%
plt.figure(figsize = (15,5))
na_counts = df_87.isna().sum()
base_color = sb.color_palette()[0]
sb.barplot(na_counts.index.values, na_counts, color=base_color)
locs, labels = plt.xticks() 
plt.xticks(np.arange(len(df_87.columns)), df_87.columns, rotation=90);

# %%
plt.figure(figsize = (15,5))
na_counts = df_08.isna().sum()
base_color = sb.color_palette()[0]
sb.barplot(na_counts.index.values, na_counts, color=base_color)
locs, labels = plt.xticks() 
plt.xticks(np.arange(len(df_08.columns)), df_08.columns, rotation=90);
